# %% [markdown]
# <a href="https://colab.research.google.com/github/Leviana2024/The-Outlier-Enablement-Team/blob/Leviana2024-patch-1/Analysis_term.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: Ipython

from IPython.display import display, HTML
display(HTML("<h1>Hello, world!</h1>"))

# %%
def __init__(self):
    self.indigenousTerms = {}
    self.colonialTerms = {}
    self.culturalContext = {}
    self.initializeData()
    self.initializeData();

# %% [markdown]
# Version of terms enchance analysis feature

# %%
# !pip install IPython

# %%
# First we must install and import the modules
# !pip install IPython
from IPython import get_ipython
from IPython.display import display, HTML
from google.colab import userdata
# We must also import these modules to handle potential errors
from google.colab.userdata import SecretNotFoundError, NotebookAccessError

# We will now add a try and except block to handle the potential error
try:
  userdata.get('secretName')
except (SecretNotFoundError, NotebookAccessError):
  print("The 'secretName' secret was not found or access is denied.")

# display html
display(HTML("<h1>Hello, world!</h1>"))

# %%
from IPython import get_ipython
from IPython.display import display, HTML

class LinguisticHeritageApp:
    def __init__(self):
        self.indigenousTerms = {}
        self.colonialTerms = {}
        self.culturalContext = {}
        self.initializeData()

    def initializeData(self):
        # Indigenous terms database (example entries)
        self.indigenousTerms["bayanihan"] = {
            "meaning": "Community spirit and cooperation",
            "language": "Tagalog",
            "culturalSignificance": "Traditional Filipino value of communal unity"
        }

        self.indigenousTerms["diwata"] = {
            "meaning": "Deity or spirit",
            "language": "Various Philippine languages",
            "culturalSignificance": "Pre-colonial spiritual beliefs"
        }

        # Colonial terms and their indigenous counterparts
        self.colonialTerms["Dios"] = {
            "indigenous": "Bathala",
            "origin": "Spanish",
            "context": "Religious terminology"
        }

    def analyzeText(self, text):
        return {
            "indigenousWords": self.findIndigenousWords(text),
            "colonialInfluence": self.assessColonialInfluence(text),
            "culturalContext": self.provideCulturalContext(text)
        }

    def findIndigenousWords(self, text):
        results = []
        for key, value in self.indigenousTerms.items():
            if key.lower() in text.lower():
                results.append({"word": key, "details": value})
        return results

    def assessColonialInfluence(self, text):
        colonialCount = 0
        indigenousCount = 0
        for key, value in self.colonialTerms.items():
            if key.lower() in text.lower():
                colonialCount += 1
            if value["indigenous"].lower() in text.lower():
                indigenousCount += 1

        return {
            "colonialTerms": colonialCount,
            "indigenousTerms": indigenousCount,
            "ratio": indigenousCount / (colonialCount or 1)
        }

    def provideCulturalContext(self, text):
        context = []
        for key, value in self.indigenousTerms.items():
            if key.lower() in text.lower():
                context.append({"term": key, "significance": value["culturalSignificance"]})
        return context

class CommunityContribution(LinguisticHeritageApp):
    def __init__(self):
        super().__init__() # call the super __init__ to inherit from LinguisticHeritageApp
        self.communitySubmissions = {}

    def submitNewTerm(self, term, details, contributor):
        self.communitySubmissions[term] = {
            **details,
            "contributor": contributor,
            "dateSubmitted": str(datetime.now()), #Use datetime to get the current time
            "status": "pending"
        }

    def reviewSubmissions(self):
        # Review process for new term submissions
        for key, value in self.communitySubmissions.items():
            print(f"Reviewing submission: {key}")
            # Implementation of review process

# Example text analysis
def analyzeUserText():
    sampleText = """
        In our bayanihan spirit, we called upon the diwata for guidance.
        While others say Dios, we remember Bathala from our ancestors.
    """

    print("Analyzing text for linguistic heritage...")
    analysis = app.analyzeText(sampleText)

    # Display results
    print("\nIndigenous Words Found:")
    for item in analysis["indigenousWords"]:
        print(f"""
            Word: {item['word']}
            Meaning: {item['details']['meaning']}
            Language: {item['details']['language']}
            Cultural Significance: {item['details']['culturalSignificance']}
        """)

    print("\nColonial Influence Assessment:")
    print(f"""
        Colonial Terms: {analysis['colonialInfluence']['colonialTerms']}
        Indigenous Terms: {analysis['colonialInfluence']['indigenousTerms']}
        Indigenous-to-Colonial Ratio: {analysis['colonialInfluence']['ratio']}
    """)

    print("\nCultural Context:")
    for item in analysis["culturalContext"]:
        print(f"""
            Term: {item['term']}
            Significance: {item['significance']}
        """)

# Initialize the application
from datetime import datetime # import datetime to display the time when a term is added
app = LinguisticHeritageApp()
communityApp = CommunityContribution()
analyzeUserText()  # Run the analysis

# Interactive UI Elements (HTML)
htmlInterface = """
<!DOCTYPE html>
<html>
<head>
    <title>Linguistic Heritage Analyzer</title>
    <style>
        .indigenous-term { color: green; font-weight: bold; }
        .colonial-term { color: red; text-decoration: underline; }
        .cultural-context { background-color: #f0f0f0; padding: 10px; }
    </style>
</head>
<body>
    <div id="analyzer">
        <h2>Linguistic Heritage Analyzer</h2>
        <textarea id="textInput" rows="5" cols="50"
            placeholder="Enter text for analysis..."></textarea>
        <button onclick="analyzeUserText()">Analyze Text</button>
        <div id="results"></div>
    </div>
</body>
</html>
"""

#display html
display(HTML(htmlInterface))

# %% [markdown]
# # New Section
# Data frame Pandas

# %% [markdown]
# # Pandas Leviana

# %%
import pandas as pd

# %%
# Install the necessary packages
# !pip install IPython
# !pip install pandas

# Import the necessary modules
from IPython import get_ipython
from IPython.display import display, HTML
from google.colab import userdata
from google.colab.userdata import SecretNotFoundError, NotebookAccessError
from datetime import datetime
import pandas as pd

# Try to get the secret
try:
    userdata.get('secretName')
except (SecretNotFoundError, NotebookAccessError):
    print("The 'secretName' secret was not found or access is denied.")

# Display HTML
display(HTML("<h1>Hello, world!</h1>"))

class LinguisticHeritageApp:
    def __init__(self):
        self.indigenousTerms = {}
        self.colonialTerms = {}
        self.culturalContext = {}
        self.initializeData()

    def initializeData(self):
        # Indigenous terms database (example entries)
        self.indigenousTerms["bayanihan"] = {
            "meaning": "Community spirit and cooperation",
            "language": "Tagalog",
            "culturalSignificance": "Traditional Filipino value of communal unity"
        }

        self.indigenousTerms["diwata"] = {
            "meaning": "Deity or spirit",
            "language": "Various Philippine languages",
            "culturalSignificance": "Pre-colonial spiritual beliefs"
        }

        # Colonial terms and their indigenous counterparts
        self.colonialTerms["Dios"] = {
            "indigenous": "Bathala",
            "origin": "Spanish",
            "context": "Religious terminology"
        }

    def analyzeText(self, text):
        return {
            "indigenousWords": self.findIndigenousWords(text),
            "colonialInfluence": self.assessColonialInfluence(text),
            "culturalContext": self.provideCulturalContext(text)
        }

    def findIndigenousWords(self, text):
        results = []
        for key, value in self.indigenousTerms.items():
            if key.lower() in text.lower():
                results.append({"word": key, "details": value})
        return results

    def assessColonialInfluence(self, text):
        colonialCount = 0
        indigenousCount = 0
        for key, value in self.colonialTerms.items():
            if key.lower() in text.lower():
                colonialCount += 1
            if value["indigenous"].lower() in text.lower():
                indigenousCount += 1

        return {
            "colonialTerms": colonialCount,
            "indigenousTerms": indigenousCount,
            "ratio": indigenousCount / (colonialCount or 1)
        }

    def provideCulturalContext(self, text):
        context = []
        for key, value in self.indigenousTerms.items():
            if key.lower() in text.lower():
                context.append({"term": key, "significance": value["culturalSignificance"]})
        return context

class CommunityContribution(LinguisticHeritageApp):
    def __init__(self):
        super().__init__()  # call the super __init__ to inherit from LinguisticHeritageApp
        self.communitySubmissions = {}

    def submitNewTerm(self, term, details, contributor):
        self.communitySubmissions[term] = {
            **details,
            "contributor": contributor,
            "dateSubmitted": str(datetime.now()),  # Use datetime to get the current time
            "status": "pending"
        }

    def reviewSubmissions(self):
        # Review process for new term submissions
        for key, value in self.communitySubmissions.items():
            print(f"Reviewing submission: {key}")
            # Implementation of review process

# Example text analysis
def analyzeUserText():
    sampleText = """
        In our bayanihan spirit, we called upon the diwata for guidance.
        While others say Dios, we remember Bathala from our ancestors.
    """

    print("Analyzing text for linguistic heritage...")
    analysis = app.analyzeText(sampleText)

    # Display results
    print("\nIndigenous Words Found:")
    for item in analysis["indigenousWords"]:
        print(f"""
            Word: {item['word']}
            Meaning: {item['details']['meaning']}
            Language: {item['details']['language']}
            Cultural Significance: {item['details']['culturalSignificance']}
        """)

    print("\nColonial Influence Assessment:")
    print(f"""
        Colonial Terms: {analysis['colonialInfluence']['colonialTerms']}
        Indigenous Terms: {analysis['colonialInfluence']['indigenousTerms']}
        Indigenous-to-Colonial Ratio: {analysis['colonialInfluence']['ratio']}
    """)

    print("\nCultural Context:")
    for item in analysis["culturalContext"]:
        print(f"""
            Term: {item['term']}
            Significance: {item['significance']}
        """)

# Initialize the application
app = LinguisticHeritageApp()
communityApp = CommunityContribution()
analyzeUserText()  # Run the analysis

# Interactive UI Elements (HTML)
htmlInterface = """
<!DOCTYPE html>
<html>
<head>
    <title>Linguistic Heritage Analyzer</title>
    <style>
        .indigenous-term { color: green; font-weight: bold; }
        .colonial-term { color: red; text-decoration: underline; }
        .cultural-context { background-color: #f0f0f0; padding: 10px; }
    </style>
</head>
<body>
    <div id="analyzer">
        <h2>Linguistic Heritage Analyzer</h2>
        <textarea id="textInput" rows="5" cols="50"
            placeholder="Enter text for analysis..."></textarea>
        <button onclick="analyzeUserText()">Analyze Text</button>
        <div id="results"></div>
    </div>
</body>
</html>
"""

# Display HTML
display(HTML(htmlInterface))

# Sample DataFrame creation and filtering
# Sample DataFrame (You would load your actual data here)
data = {'col1': [1, 2, 3, 4, 5],
        'col2': ['A', 'B', 'A', 'C', 'B'],
        'col3': [10, 20, 15, 25, 30]}
df = pd.DataFrame(data)

# Condition: select rows where 'col1' is greater than 2
condition = df['col1'] > 2

# Filter the DataFrame
filtered_df = df[condition]

# To see the output, run the code.
print(filtered_df)

# Another filter can be applied.
condition2 = df['col2'] == 'A'
filtered_df2 = df[condition2]

# To see the output, run the code.
print(filtered_df2)

# %% [markdown]
# # New Section
